# %% [markdown]
# ### laalvarado@ine.gob.gt

# %%
import pandas as pd

# %%
df = pd.read_csv(
    "db/NetFlix.csv",
    dtype={
        "release_year":"int16",
        "duration":"int16"
    }
)
df["date_added"] = pd.to_datetime(df["date_added"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   datetime64[ns]
#  7   release_year  7787 non-null   int16
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int16
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: datetime64[ns](1), int16(2), object(9)
# memory usage: 638.9+ KB

# %%
df.head(3)
# Out:
#   show_id     type       title        director  \
# 0     x01  TV Show   Wednesday
# 1     s10    Movie        1933    Vikram Bhatt
# 2    s100    Movie  3 Heroines  Iman Brotoseno
#
#                                                 cast        country  \
# 0                                                     United States
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...          India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...      Indonesia
#
#             date_added  release_year rating  duration  \
# 0             2023-3-1          2023  PG-13         1
# 1  2017-12-15 00:00:00          2008  TV-MA       143
# 2  2019-01-05 00:00:00          2016  TV-PG       124
#
#                                            genres  \
# 0                                          Comedy
# 1  Horror Movies, International Movies, Thrillers
# 2     Dramas, International Movies, Sports Movies
#
#                                          description  duration_min continente
# ...

# %%
df.loc[df["title"]=="Wednesday"]
# Out:
#      show_id     type      title director cast        country  date_added  \
# 7787     x01  TV Show  Wednesday                United States  2022-12-12
# 7788     x01  TV Show  Wednesday                United States  2022-12-12
# 7789     x01  TV Show  Wednesday                United States  2022-12-12
# 7790     x01  TV Show  Wednesday                United States    2023-3-1
#
#       release_year rating  duration  genres description
# 7787          2022  PG-13         1  Comedy
# 7788          2022  PG-13         1  Comedy
# 7789          2022  PG-13         1  Comedy
# 7790          2023  PG-13         1  Comedy

# %%
datos_Wednesday = [
    "x01",
    "TV Show",
    "Wednesday",
    "",
    "",
    "United States",
    "2023-3-1",
    2023,
    "PG-13",
    1,
    "Comedy",
    ""
]
df.loc[0] = datos_Wednesday

# %%
df.iloc[1,2] = "1933"

# %%
df["duration_min"] = df["duration"] * 60

# %%
from numpy import nan
def continente(pais):
    america = ("United States", "Guatemala")
    if pais in america:
        return "America"
    else:
        return nan

df["country"].apply(continente)
# Out:
# 0       America
# 1           NaN
# 2           NaN
# 3       America
# 4           NaN
#          ...
# 7786    America
# 7787    America
# 7788    America
# 7789    America
# 7790    America
# Name: country, Length: 7791, dtype: object

# %%
df["continente"] = df["country"].apply(continente)

# %% [markdown]
# # Borrar

# %%
df = df.drop([1,10])

# %%
df.drop_duplicates().tail(4)
# Out:
#      show_id     type         title      director  \
# 7785    s998    Movie  Blue Jasmine   Woody Allen
# 7786    s999    Movie      Blue Jay  Alex Lehmann
# 7787     x01  TV Show     Wednesday
# 7790     x01  TV Show     Wednesday
#
#                                                    cast        country  \
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...  United States
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager  United States
# 7787                                                     United States
# 7790                                                     United States
#
#                date_added  release_year rating  duration  \
# 7785  2019-03-08 00:00:00          2013  PG-13        98
# 7786  2016-12-06 00:00:00          2016  TV-MA        81
# 7787           2022-12-12          2022  PG-13         1
# 7790             2023-3-1          2023  PG-13         1
#
#                                            genres  \
# ...

# %%
df = df.drop(["cast", "rating"], axis=1)

# %% [markdown]
# # Extra

# %%
df_gba = pd.read_csv(
    'db/serie_gba.csv',
    dtype={
        "RegCod":"int8",
        "PerAno":"int16",
        "PerMes":"int8"
    },
    converters={"GbaNom":str.strip}
)
df_gba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359303 entries, 0 to 359302
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   RegCod  359303 non-null  int8
#  1   PerAno  359303 non-null  int16
#  2   PerMes  359303 non-null  int8
#  3   GbaInd  359303 non-null  float64
#  4   GbaNom  359303 non-null  object
# dtypes: float64(1), int16(1), int8(2), object(1)
# memory usage: 6.9+ MB

# %%
df_gba.query('RegCod==0 and GbaNom=="ARROZ" and GbaInd >= 117')["GbaInd"].mean()
# Out:
# 117.8841810068493

# %%
x = df_gba.loc[(df_gba["RegCod"]==0) & (df_gba["GbaNom"]=="ARROZ") & (df_gba["GbaInd"] >= 117.8), ["GbaInd"]]
nuevos_datos = len(x)*[117.88]
df_gba.loc[(df_gba["RegCod"]==0) & (df_gba["GbaNom"]=="ARROZ") & (df_gba["GbaInd"] >= 117.8), ["GbaInd"]] = nuevos_datos

# %%
df_gba.loc[(df_gba["RegCod"]==0) & (df_gba["GbaNom"]=="ARROZ") & (df_gba["GbaInd"] >= 117.8), ["GbaInd"]]
# Out:
#         GbaInd
# 249056  117.88
# 249103  117.88
# 249150  117.88
# 249383  117.88
# 249430  117.88
# 249477  117.88
# 285103  117.88
# 285150  117.88
# 285197  117.88
# 285244  117.88
# 285309  117.88
# 285356  117.88
# 285403  117.88
# 285450  117.88
# 285497  117.88
# 285572  117.88
# 285619  117.88
# 285666  117.88
# 308096  117.88
# 308116  117.88
# 308221  117.88
# 308268  117.88
# 308315  117.88
# 308362  117.88
# 308409  117.88
# 308456  117.88
# 308504  117.88
# 308551  117.88
# 308598  117.88
# 308645  117.88
# 344239  117.88
# 344286  117.88
# 344333  117.88
# 344380  117.88
# 344427  117.88
# 344474  117.88
# 344521  117.88
# 344552  117.88
# 344599  117.88
# 344688  117.88
# 344735  117.88
# 344782  117.88
# 357704  117.88
